# %%
import pandas as pd
from src.detection import find_daily_touches, find_weekly_touches

# Pick a ticker you know exists, e.g. NVDA
daily  = find_daily_touches("NVDA")
weekly = find_weekly_touches("NVDA")

# Inspect
print("Daily touches (first 5):")
print(daily.head())

print("\nWeekly touches (first 5):")
print(weekly.head())

# Sanity-check your known dates landed in the daily set:
for dt in ["2024-04-19","2024-08-05","2025-01-27","2025-04-04","2025-04-07"]:
    print(dt, pd.to_datetime(dt) in daily.index)
# Out:
# Daily touches (first 5):
#                Close      High       Low      Open      Volume  MACD_12_26_9  \
# Date
# 2007-03-05  0.439549  0.455902  0.438021  0.447038   663558000     -0.012788
# 2008-01-04  0.687751  0.731996  0.683166  0.728328   736092000     -0.004989
# 2008-01-07  0.616683  0.698067  0.604074  0.692336  1006800000     -0.016759
# 2008-01-08  0.629750  0.671474  0.605679  0.620122  1106956000     -0.024748
# 2008-01-09  0.662304  0.662533  0.628833  0.638233   741036000     -0.028128
#
#             MACDh_12_26_9  MACDs_12_26_9     RSI_14  Elder_Force_Index_2  \
# Date
# 2007-03-05      -0.006079      -0.006709  28.111642        -9.310785e+06
# 2008-01-04      -0.010232       0.005244  33.710840        -3.254894e+07
# 2008-01-07      -0.017602       0.000843  26.573966        -5.855008e+07
# 2008-01-08      -0.020473      -0.004275  29.528261        -9.873406e+06
# 2008-01-09      -0.019082      -0.009046  36.394142         1.279104e+07
#
# ...
